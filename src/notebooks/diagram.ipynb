# %%
import pandas as pd

# %%
df=pd.read_csv(r'..\\..\\public\\01.revenue_per_payment_type.csv',sep=',',encoding='utf8')

# %%
df.plot(x='payment_type', title='Revenue per payment type',kind='bar')
# Out:
# <Axes: title={'center': 'Revenue per payment type'}, xlabel='payment_type'>

# %%
df=pd.read_csv(r'..\\..\\public\\02.revenues_per_companies.csv',sep=',',encoding='utf8')

# %%
df.plot(x='company', title='Revenue per company',kind='bar')
# Out:
# <Axes: title={'center': 'Revenue per company'}, xlabel='company'>

# %%
df=pd.read_csv(r'..\\..\\public\\03.taxi_trips_by_hour.csv',sep=',',encoding='utf8')

# %%
df.plot(x='hours', title='Daily trips by hours', kind='bar')
# Out:
# <Axes: title={'center': 'Daily trips by hours'}, xlabel='hours'>

# %%
df=pd.read_csv(r'..\\..\\public\\04.revenues_per_areas.csv',sep=',',encoding='utf8')

# %%
df.plot(x='community name', title='Revenue per areas',kind='bar')
# Out:
# <Axes: title={'center': 'Revenue per areas'}, xlabel='community name'>

# %%
df=pd.read_csv(r'..\\..\\public\\05a.pickup_from_ohara_per_companies.csv',sep=',',encoding='utf8')
df2=pd.read_csv(r'..\\..\\public\\05b.dropoff_at_ohara_per_companies.csv',sep=',',encoding='utf8')
df=pd.merge(df,df2, left_on='company', right_on='company', how='left' )

# %%
df.head(20)
# Out:
#    from_OHare_district_trip_number                            company  \
# 0                             2193       Taxicab Insurance Agency Llc
# 1                             2157                           Sun Taxi
# 2                             1998  Transit Administrative Center Inc
# 3                             1521                       City Service
# 4                             1318                          Flash Cab
# 5                             1179               Chicago Independents
# 6                             1066                        5 Star Taxi
# 7                              517                         Globe Taxi
# 8                              427                   Medallion Leasin
# 9                              340       Blue Ribbon Taxi Association
#
#    to_OHare_district_trip_number
# 0                          268.0
# 1                          223.0
# 2                          278.0
# 3                          186.0
# ...

# %%
df.plot(x='company', title="Pickup and dropoff of area O'Hare",kind='bar')
# Out:
# <Axes: title={'center': "Pickup and dropoff of area O'Hare"}, xlabel='company'>
