# %%
from datetime import datetime
from dateutil.relativedelta import relativedelta

import pandas as pd
pd.set_option("display.max_columns",30)
import requests

# %%
current_datetime=datetime.now() - relativedelta(months=2)
formatted_datetime=current_datetime.strftime("%Y-%m-%d")


url= (
    f"https://data.cityofchicago.org/api/v3/views/ajtu-isnz/query.json?app_token=ogjssL0qdXCJ16jANDq5lFDLc"
    f"&query=select * where trip_start_timestamp>='{formatted_datetime}T00:00:00' AND trip_start_timestamp<='{formatted_datetime}T23:59:59'"

)
response=requests.get(url)
data=response.json()

len(data)
# Out:
# 23174

# %%
print ("https://data.cityofchicago.org/api/v3/views/ajtu-isnz/query.json?app_token=ogjssL0qdXCJ16jANDq5lFDLc"
    f"&query=select * where trip_start_timestamp>='"+formatted_datetime+"'")
# Out:
# https://data.cityofchicago.org/api/v3/views/ajtu-isnz/query.json?app_token=ogjssL0qdXCJ16jANDq5lFDLc&query=select * where trip_start_timestamp>='2025-09-26'

# %%
taxi_trips=pd.DataFrame(data)

taxi_trips.head()
# Out:
#                                     trip_id  \
# 0  5887b84e350521b3d1c9b31f6e9a5a4ef39be5d6
# 1  006d64de27bc9d408ccb3fda78ff2d643334aee7
# 2  03fddd4b286099fe548254b40e2ee57bb6865375
# 3  043c9bde3029eb5a436ba33acfe379c89a49bf36
# 4  052b170224311f9b4f4eff285dcfe23a03fcc68d
#
#                                              taxi_id     trip_start_timestamp  \
# 0  3618045f9110d4d88482266ade23659c1a50d32ac37f20...  2025-09-26T23:45:00.000
# 1  6c1e4e8e25a1b47575b359c5a0844cf23c50e540a86ecd...  2025-09-26T23:45:00.000
# 2  8123ec5a70681a139fcd93fd477eec0ee05dda82987748...  2025-09-26T23:45:00.000
# 3  a0f44bc0a273e49230e4abe4d0a8d3a1e8305945f8fa0b...  2025-09-26T23:45:00.000
# 4  d032016cdde07ebbac8ab34b98a534aed192e1c86d610f...  2025-09-26T23:45:00.000
#
#         trip_end_timestamp trip_seconds trip_miles pickup_community_area  \
# 0  2025-09-27T00:00:00.000          783       2.99                    22
# 1  2025-09-26T23:45:00.000          630       1.39                     8
# 2  2025-09-27T00:00:00.000          751       4.18                     8
# 3  2025-09-27T00:15:00.000         1464       8.65                    33
# 4  2025-09-27T00:00:00.000          452       2.81                    76
#
#   dropoff_community_area   fare  tips tolls extras trip_total payment_type  \
# 0                     16  10.39  3.31     0      0       14.2       Mobile
# 1                      8      8     3     0      0       11.5  Credit Card
# 2                      6  15.77     0     0      0      16.27       Mobile
# 3                     23  35.52     0     0      0      36.02       Mobile
# 4                     76   9.75     2     0      4      16.25  Credit Card
#
#                         company pickup_centroid_latitude  \
# 0  Tac - Yellow Cab Association              41.92276062
# 1                     Flash Cab             41.899602111
# 2                    Globe Taxi             41.899602111
# 3                    Globe Taxi             41.857183858
# 4              Medallion Leasin             41.980264315
#
#   pickup_centroid_longitude  \
# 0             -87.699155343
# 1             -87.633308037
# 2             -87.633308037
# 3             -87.620334624
# 4             -87.913624596
#
#                             pickup_centroid_location  \
# 0  {'type': 'Point', 'coordinates': [-87.69915534...
# 1  {'type': 'Point', 'coordinates': [-87.63330803...
# 2  {'type': 'Point', 'coordinates': [-87.63330803...
# 3  {'type': 'Point', 'coordinates': [-87.62033462...
# 4  {'type': 'Point', 'coordinates': [-87.91362459...
#
#   dropoff_centroid_latitude dropoff_centroid_longitude  \
# 0              41.953582125               -87.72345239
# 1              41.899602111              -87.633308037
# 2              41.944226601              -87.655998182
# 3              41.900069603              -87.720918238
# 4              41.980264315              -87.913624596
#
#                            dropoff_centroid_location                 :id  \
# 0  {'type': 'Point', 'coordinates': [-87.72345239...  row-w32b~guyt.ft7m
# 1  {'type': 'Point', 'coordinates': [-87.63330803...  row-5aig.z528_ajd5
# 2  {'type': 'Point', 'coordinates': [-87.65599818...  row-xswe_qdmz-ry8r
# 3  {'type': 'Point', 'coordinates': [-87.72091823...  row-gqws.23cs~dew6
# 4  {'type': 'Point', 'coordinates': [-87.91362459...  row-memd~9u4e.246j
#
#             :version               :created_at               :updated_at  \
# 0  rv-52c8-tce2-t9e9  2025-10-09T18:15:56.782Z  2025-10-09T18:15:56.782Z
# 1  rv-tspa~efbc_d3ug  2025-10-09T18:15:56.782Z  2025-10-09T18:15:56.782Z
# 2  rv-y9xm.57mw~mi9c  2025-10-09T18:15:56.782Z  2025-10-09T18:15:56.782Z
# 3  rv-ywvv-6kjh-brs5  2025-10-09T18:15:56.782Z  2025-10-09T18:15:56.782Z
# 4  rv-xggw.vrvy_4rcu  2025-10-09T18:15:56.782Z  2025-10-09T18:15:56.782Z
#
#   pickup_census_tract dropoff_census_tract
# 0                 NaN                  NaN
# 1                 NaN                  NaN
# 2                 NaN                  NaN
# 3                 NaN                  NaN
# 4                 NaN                  NaN

# %%
taxi_trips.tail()
# Out:
#                                         trip_id  \
# 23169  2ec96e4a3512f35645d6b4e88df548e79c1abd87
# 23170  2db30833ebb4fbc2c22b119f34f8c232851b3447
# 23171  116891f6e645aa8a310b74a3d20d31f36eaa4a79
# 23172  28f2ee5349ed24f36a4040f83bf7f97546604fc5
# 23173  25d1f1e46b73a098c2d566bdf9da91ef603e7838
#
#                                                  taxi_id  \
# 23169  1e320d8fd4e4610d538453cec33d541acf1bd1591a17ee...
# 23170  5e6ba3d77c1e1597624402bd204e81b4acbc3bdb103741...
# 23171  8d75a4e15682364840d85e0f9f954e98b2703f4e252e88...
# 23172  af6fed00f40ccaeabf990aca8ad19696c7f4d989805167...
# 23173  b951b7af9a405d88275b77b6a04970bc2085661297b5e6...
#
#           trip_start_timestamp       trip_end_timestamp trip_seconds  \
# 23169  2025-09-26T00:00:00.000  2025-09-26T00:15:00.000          874
# 23170  2025-09-26T00:00:00.000  2025-09-26T00:15:00.000          720
# 23171  2025-09-26T00:00:00.000  2025-09-26T00:15:00.000         1020
# 23172  2025-09-26T00:00:00.000  2025-09-26T00:00:00.000          344
# 23173  2025-09-26T00:00:00.000  2025-09-26T00:30:00.000         1301
#
#       trip_miles pickup_community_area dropoff_community_area   fare  tips  \
# 23169       6.81                     3                     32  24.52     0
# 23170        6.4                    76                     10  18.25   4.5
# 23171         10                    56                     28  26.25  6.15
# 23172       1.71                    76                    NaN     25     1
# 23173      17.28                    76                      8     43   9.5
#
#       tolls extras trip_total payment_type                            company  \
# 23169     0      0      25.02       Mobile                           Sun Taxi
# 23170     0      4      26.75  Credit Card  Transit Administrative Center Inc
# 23171     0      4       36.4  Credit Card  Transit Administrative Center Inc
# 23172     0      0       26.5  Credit Card                           Sun Taxi
# 23173     0      4         57  Credit Card                        5 Star Taxi
#
#       pickup_centroid_latitude pickup_centroid_longitude  \
# 23169             41.958055933             -87.660389456
# 23170             41.980264315             -87.913624596
# 23171              41.79259236             -87.769615453
# 23172             41.980264315             -87.913624596
# 23173              41.97907082             -87.903039661
#
#                                 pickup_centroid_location  \
# 23169  {'type': 'Point', 'coordinates': [-87.66038945...
# 23170  {'type': 'Point', 'coordinates': [-87.91362459...
# 23171  {'type': 'Point', 'coordinates': [-87.76961545...
# 23172  {'type': 'Point', 'coordinates': [-87.91362459...
# 23173  {'type': 'Point', 'coordinates': [-87.90303966...
#
#       dropoff_centroid_latitude dropoff_centroid_longitude  \
# 23169              41.880994471              -87.632746489
# 23170              41.985015101              -87.804532006
# 23171              41.874005383               -87.66351755
# 23172                       NaN                        NaN
# 23173              41.892042136               -87.63186395
#
#                                dropoff_centroid_location                 :id  \
# 23169  {'type': 'Point', 'coordinates': [-87.63274648...  row-xcde-mwsp~dvd9
# 23170  {'type': 'Point', 'coordinates': [-87.80453200...  row-bzyu-bdfc-jbc9
# 23171  {'type': 'Point', 'coordinates': [-87.66351754...  row-zbqn_ibns_pt24
# 23172                                                NaN  row-e7ux_q6rk-4pz6
# 23173  {'type': 'Point', 'coordinates': [-87.63186394...  row-ecnt~eh9a.52kb
#
#                 :version               :created_at               :updated_at  \
# 23169  rv-47pg_er7n.2dnw  2025-10-09T18:15:56.782Z  2025-10-09T18:15:56.782Z
# 23170  rv-7g9c-x62t_kade  2025-10-09T18:15:56.782Z  2025-10-09T18:15:56.782Z
# 23171  rv-2dgy~efwd_ugfp  2025-10-09T18:15:56.782Z  2025-10-09T18:15:56.782Z
# 23172  rv-q8a3-hs4q-7wi8  2025-10-09T18:15:56.782Z  2025-10-09T18:15:56.782Z
# 23173  rv-3skh.3xb3_ngrw  2025-10-09T18:15:56.782Z  2025-10-09T18:15:56.782Z
#
#       pickup_census_tract dropoff_census_tract
# 23169         17031830700          17031839100
# 23170                 NaN                  NaN
# 23171                 NaN                  NaN
# 23172                 NaN                  NaN
# 23173         17031980000          17031081700

# %%
taxi_trips.sample(5)
# Out:
#                                         trip_id  \
# 3237   7d6ec4852a32be266da62d0048b7669893f0c8c3
# 4625   a9e0a47c1b6e8775782fd37514350a115f55d2f7
# 11198  b40ee6bcb7b0680c2bc38c5a08c566f4fbc3127b
# 16782  654fa30f5065ca9caa8f3942703e189668fd5660
# 1078   7c2953686b1af28bcd8ff0e796ad3d04c16e49e9
#
#                                                  taxi_id  \
# 3237   46c4778c3a32454511f96752c509c608955e293da45dbf...
# 4625   c52f389ae4d868380527db070d00352de61e235d5e3f87...
# 11198  a2c933ca0489813d4f5b49f79aa6c6b5701ef589bdc503...
# 16782  4972764cee12598f449342da6c1c3f3686f6e800184eba...
# 1078   c81a672f30763423ddc7abac2b2e20a2f1ea045088ef77...
#
#           trip_start_timestamp       trip_end_timestamp trip_seconds  \
# 3237   2025-09-26T19:45:00.000  2025-09-26T19:45:00.000            0
# 4625   2025-09-26T18:45:00.000  2025-09-26T19:00:00.000         1220
# 11198  2025-09-26T14:45:00.000  2025-09-26T15:00:00.000          641
# 16782  2025-09-26T11:15:00.000  2025-09-26T12:15:00.000         3591
# 1078   2025-09-26T22:00:00.000  2025-09-26T22:15:00.000          379
#
#       trip_miles pickup_community_area dropoff_community_area   fare  tips  \
# 3237           0                     8                      8   3.25     0
# 4625        6.46                    32                     38  19.75     0
# 11198       1.61                    32                      8    8.5  1.82
# 16782      17.97                    76                     32     46  10.1
# 1078        1.48                    28                      8   6.75     0
#
#       tolls extras trip_total payment_type                            company  \
# 3237      0      0       3.25         Cash  Transit Administrative Center Inc
# 4625      0      0      19.75       Prcard                          Flash Cab
# 11198     0      0      10.82       Mobile       Taxicab Insurance Agency Llc
# 16782     0      4       60.6  Credit Card                          Flash Cab
# 1078      0      0       6.75         Cash                          Flash Cab
#
#       pickup_centroid_latitude pickup_centroid_longitude  \
# 3237              41.892507781             -87.626214906
# 4625              41.878865584             -87.625192142
# 11198             41.880994471             -87.632746489
# 16782              41.97907082             -87.903039661
# 1078              41.874005383              -87.66351755
#
#                                 pickup_centroid_location  \
# 3237   {'type': 'Point', 'coordinates': [-87.62621490...
# 4625   {'type': 'Point', 'coordinates': [-87.62519214...
# 11198  {'type': 'Point', 'coordinates': [-87.63274648...
# 16782  {'type': 'Point', 'coordinates': [-87.90303966...
# 1078   {'type': 'Point', 'coordinates': [-87.66351754...
#
#       dropoff_centroid_latitude dropoff_centroid_longitude  \
# 3237               41.892507781              -87.626214906
# 4625               41.812948939              -87.617859676
# 11198              41.907520075                -87.6266589
# 16782              41.877406123              -87.621971652
# 1078               41.899602111              -87.633308037
#
#                                dropoff_centroid_location                 :id  \
# 3237   {'type': 'Point', 'coordinates': [-87.62621490...  row-rtxi-h7j5_4uar
# 4625   {'type': 'Point', 'coordinates': [-87.61785967...  row-2hce_qcha-r4tm
# 11198  {'type': 'Point', 'coordinates': [-87.62665890...  row-mgjx.exxr~cy5x
# 16782  {'type': 'Point', 'coordinates': [-87.62197165...  row-itrj_dixh_3dey
# 1078   {'type': 'Point', 'coordinates': [-87.63330803...  row-enqs~cby9-hjvv
#
#                 :version               :created_at               :updated_at  \
# 3237   rv-jykx_gyig_2kqp  2025-10-09T18:15:56.782Z  2025-10-09T18:15:56.782Z
# 4625   rv-abis~99b8_khv4  2025-10-09T18:15:56.782Z  2025-10-09T18:15:56.782Z
# 11198  rv-724b~p49n-r4th  2025-10-09T18:15:56.782Z  2025-10-09T18:15:56.782Z
# 16782  rv-pd4d_azte.jft3  2025-10-09T18:15:56.782Z  2025-10-09T18:15:56.782Z
# 1078   rv-yfnf_5xg2-ugs6  2025-10-09T18:15:56.782Z  2025-10-09T18:15:56.782Z
#
#       pickup_census_tract dropoff_census_tract
# 3237          17031081500          17031081500
# 4625                  NaN                  NaN
# 11198         17031839100          17031080100
# 16782         17031980000          17031320400
# 1078                  NaN                  NaN

# %%
taxi_trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23174 entries, 0 to 23173
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   trip_id                     23174 non-null  object
#  1   taxi_id                     23174 non-null  object
#  2   trip_start_timestamp        23174 non-null  object
#  3   trip_end_timestamp          23173 non-null  object
#  4   trip_seconds                23172 non-null  object
#  5   trip_miles                  23174 non-null  object
#  6   pickup_community_area       22524 non-null  object
#  7   dropoff_community_area      21254 non-null  object
#  8   fare                        23134 non-null  object
#  9   tips                        23134 non-null  object
#  10  tolls                       23134 non-null  object
#  11  extras                      23134 non-null  object
#  12  trip_total                  23134 non-null  object
#  13  payment_type                23174 non-null  object
#  14  company                     23174 non-null  object
#  15  pickup_centroid_latitude    22525 non-null  object
#  16  pickup_centroid_longitude   22525 non-null  object
#  17  pickup_centroid_location    22525 non-null  object
#  18  dropoff_centroid_latitude   21326 non-null  object
#  19  dropoff_centroid_longitude  21326 non-null  object
#  20  dropoff_centroid_location   21326 non-null  object
#  21  :id                         23174 non-null  object
#  22  :version                    23174 non-null  object
#  23  :created_at                 23174 non-null  object
#  24  :updated_at                 23174 non-null  object
#  25  pickup_census_tract         10779 non-null  object
#  26  dropoff_census_tract        10550 non-null  object
# dtypes: object(27)
# memory usage: 4.8+ MB

# %%
taxi_trips[taxi_trips["fare"].isna()].sample(5)
# Out:
#                                         trip_id  \
# 9158   eedf13c076abca7595f4e289fa1c59dc3e906216
# 3745   d8c8d92ff6947a762ccdb8d179ac630ec882ba3a
# 17425  66e944ce33e02b916f3dcfbe2766843a1ac205e7
# 10769  dd5bc115d46daef8fb4025b6a3c9837ea29e9187
# 19040  337de6933f1b23fda722c47fd2270a8030060353
#
#                                                  taxi_id  \
# 9158   58dd35601f224bc255e2d882fee540d5cabf30cabc55cf...
# 3745   64fef3c62cbbc9dd8c00e7e1cf6d29ea73d9ebdd758d4f...
# 17425  2407ff99e367ceb469a8cc6663e6ad6ec51fb0f401d370...
# 10769  c7e24b57c5ac5cc6b23bdaa7ad986c639f07680587bf71...
# 19040  574b161e75a7dda9dc1f63751af8b83c982a3a76f5fc88...
#
#           trip_start_timestamp       trip_end_timestamp trip_seconds  \
# 9158   2025-09-26T16:00:00.000  2025-09-26T16:00:00.000            5
# 3745   2025-09-26T19:15:00.000  2025-09-26T21:00:00.000         6741
# 17425  2025-09-26T10:45:00.000  2025-09-26T11:15:00.000         1807
# 10769  2025-09-26T15:00:00.000  2025-09-26T15:15:00.000          826
# 19040  2025-09-26T09:30:00.000  2025-09-26T10:00:00.000         2464
#
#       trip_miles pickup_community_area dropoff_community_area fare tips tolls  \
# 9158           0                    76                     76  NaN  NaN   NaN
# 3745       19.46                    76                      8  NaN  NaN   NaN
# 17425      11.23                    76                     16  NaN  NaN   NaN
# 10769        3.1                    10                     15  NaN  NaN   NaN
# 19040      17.94                    76                      8  NaN  NaN   NaN
#
#       extras trip_total payment_type                       company  \
# 9158     NaN        NaN         Cash                  City Service
# 3745     NaN        NaN         Cash                   5 Star Taxi
# 17425    NaN        NaN         Cash          Chicago Independents
# 10769    NaN        NaN         Cash                   5 Star Taxi
# 19040    NaN        NaN         Cash  Taxicab Insurance Agency Llc
#
#       pickup_centroid_latitude pickup_centroid_longitude  \
# 9158               41.97907082             -87.903039661
# 3745               41.97907082             -87.903039661
# 17425             41.980264315             -87.913624596
# 10769             41.985015101             -87.804532006
# 19040              41.97907082             -87.903039661
#
#                                 pickup_centroid_location  \
# 9158   {'type': 'Point', 'coordinates': [-87.90303966...
# 3745   {'type': 'Point', 'coordinates': [-87.90303966...
# 17425  {'type': 'Point', 'coordinates': [-87.91362459...
# 10769  {'type': 'Point', 'coordinates': [-87.80453200...
# 19040  {'type': 'Point', 'coordinates': [-87.90303966...
#
#       dropoff_centroid_latitude dropoff_centroid_longitude  \
# 9158                41.97907082              -87.903039661
# 3745               41.899155613              -87.626210532
# 17425              41.953582125               -87.72345239
# 10769              41.954027649              -87.763399032
# 19040               41.89503345              -87.619710672
#
#                                dropoff_centroid_location                 :id  \
# 9158   {'type': 'Point', 'coordinates': [-87.90303966...  row-hkix~49uu_igvb
# 3745   {'type': 'Point', 'coordinates': [-87.62621053...  row-x2u5_7gyu-sht6
# 17425  {'type': 'Point', 'coordinates': [-87.72345239...  row-d8cn~wbxn-sawv
# 10769  {'type': 'Point', 'coordinates': [-87.76339903...  row-bk3h_cbn6~fjtk
# 19040  {'type': 'Point', 'coordinates': [-87.61971067...  row-wjuu~dqyd~hpqt
#
#                 :version               :created_at               :updated_at  \
# 9158   rv-5iqe_rafu_2eth  2025-10-09T18:15:56.782Z  2025-10-09T18:15:56.782Z
# 3745   rv-46j8_95tm~at5b  2025-10-09T18:15:56.782Z  2025-10-09T18:15:56.782Z
# 17425  rv-285m.4av8_rhhy  2025-10-09T18:15:56.782Z  2025-10-09T18:15:56.782Z
# 10769  rv-c6b4-qeyt.w4zz  2025-10-09T18:15:56.782Z  2025-10-09T18:15:56.782Z
# 19040  rv-dyuu.r6eh~85wk  2025-10-09T18:15:56.782Z  2025-10-09T18:15:56.782Z
#
#       pickup_census_tract dropoff_census_tract
# 9158          17031980000          17031980000
# 3745          17031980000          17031081201
# 17425                 NaN                  NaN
# 10769                 NaN                  NaN
# 19040         17031980000          17031081401

# %% [markdown]
# ### Transformation/Deal vith NaN values

# %%
taxi_trips.drop(["pickup_census_tract","dropoff_census_tract"],axis=1,inplace=True)

# %%
taxi_trips.drop(["pickup_centroid_location","dropoff_centroid_location"],axis=1,inplace=True)

# %%
taxi_trips.dropna(inplace=True)   #ha valamelyik rekordban Nan van akkor az egész rekordot törli (adattisztítás)

# %%
taxi_trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21003 entries, 0 to 23173
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   trip_id                     21003 non-null  object
#  1   taxi_id                     21003 non-null  object
#  2   trip_start_timestamp        21003 non-null  object
#  3   trip_end_timestamp          21003 non-null  object
#  4   trip_seconds                21003 non-null  object
#  5   trip_miles                  21003 non-null  object
#  6   pickup_community_area       21003 non-null  object
#  7   dropoff_community_area      21003 non-null  object
#  8   fare                        21003 non-null  object
#  9   tips                        21003 non-null  object
#  10  tolls                       21003 non-null  object
#  11  extras                      21003 non-null  object
#  12  trip_total                  21003 non-null  object
#  13  payment_type                21003 non-null  object
#  14  company                     21003 non-null  object
#  15  pickup_centroid_latitude    21003 non-null  object
#  16  pickup_centroid_longitude   21003 non-null  object
#  17  dropoff_centroid_latitude   21003 non-null  object
#  18  dropoff_centroid_longitude  21003 non-null  object
#  19  :id                         21003 non-null  object
#  20  :version                    21003 non-null  object
#  21  :created_at                 21003 non-null  object
#  22  :updated_at                 21003 non-null  object
# dtypes: object(23)
# memory usage: 3.8+ MB

# %% [markdown]
# ### Transformation/renaming

# %%
taxi_trips.rename(columns={"pickup_community_area":"pickup_community_area_id",
                           "dropoff_community_area":"dropoff_community_area_id"},inplace=True)

# %%
taxi_trips.columns
# Out:
# Index(['trip_id', 'taxi_id', 'trip_start_timestamp', 'trip_end_timestamp',
#        'trip_seconds', 'trip_miles', 'pickup_community_area_id',
#        'dropoff_community_area_id', 'fare', 'tips', 'tolls', 'extras',
#        'trip_total', 'payment_type', 'company', 'pickup_centroid_latitude',
#        'pickup_centroid_longitude', 'dropoff_centroid_latitude',
#        'dropoff_centroid_longitude', ':id', ':version', ':created_at',
#        ':updated_at'],
#       dtype='object')

# %% [markdown]
# ###Trasformation:create helper columns for weather and date dimension

# %%
taxi_trips["trip_start_timestamp"]=pd.to_datetime(taxi_trips["trip_start_timestamp"])

# %%
taxi_trips["datetime_for_weather"]=taxi_trips["trip_start_timestamp"].dt.floor("h")   
#az adatok negyedórásak, órássa alakítja hogy joinolni lehessen a weather adattal (ponots egyezés szükséges)
taxi_trips["datetime_for_weather"].sample(11)
# Out:
# 315     2025-09-26 23:00:00
# 21160   2025-09-26 07:00:00
# 14988   2025-09-26 12:00:00
# 8022    2025-09-26 16:00:00
# 1906    2025-09-26 21:00:00
# 367     2025-09-26 23:00:00
# 3356    2025-09-26 19:00:00
# 3535    2025-09-26 19:00:00
# 4453    2025-09-26 19:00:00
# 944     2025-09-26 22:00:00
# 2835    2025-09-26 20:00:00
# Name: datetime_for_weather, dtype: datetime64[ns]

# %% [markdown]
# taxi_trips["trip_start_date"]=pd.to_datetime(taxi_trips["trip_start_timestamp"]).dt.date
# taxi_trips["trip_start_date"].sample(5)

# %% [markdown]
# ### check: join taxi and weather data

# %%
current_datetime=datetime.now() - relativedelta(months=2)
formatted_datetime=current_datetime.strftime("%Y-%m-%d")

url="https://archive-api.open-meteo.com/v1/era5"

params={

    "latitude": 41.85,
    "longitude": -87.65,
    "start_date":formatted_datetime,
    "end_date":formatted_datetime,
    "hourly":"temperature_2m,wind_speed_10m,rain,precipitation"

}

response=requests.get(url,params=params)
data=response.json()

weather_data ={
    "datetime" : data["hourly"]["time"],
    "temperature" : data["hourly"]["temperature_2m"],
    "wind_speed" : data["hourly"]["wind_speed_10m"],
    "rain" : data["hourly"]["rain"],
    "precipitation" : data["hourly"]["precipitation"]
}

weather_df = pd.DataFrame(weather_data)
weather_df["datetime"] = pd.to_datetime(weather_df["datetime"] )

weather_df.sample(11)
# Out:
#               datetime  temperature  wind_speed  rain  precipitation
# 1  2025-09-26 01:00:00         17.6         3.1   0.0            0.0
# 17 2025-09-26 17:00:00         23.8         9.9   0.0            0.0
# 18 2025-09-26 18:00:00         24.9         9.0   0.0            0.0
# 23 2025-09-26 23:00:00         24.3         9.7   0.0            0.0
# 13 2025-09-26 13:00:00         14.9        10.0   0.0            0.0
# 0  2025-09-26 00:00:00         17.5         2.2   0.0            0.0
# 5  2025-09-26 05:00:00         16.0         4.4   0.0            0.0
# 8  2025-09-26 08:00:00         15.0         6.2   0.0            0.0
# 11 2025-09-26 11:00:00         14.4         8.0   0.0            0.0
# 16 2025-09-26 16:00:00         22.1         9.0   0.0            0.0
# 14 2025-09-26 14:00:00         16.8         7.7   0.0            0.0

# %%
taxi_trips_with_weather=taxi_trips.merge(weather_df,left_on="datetime_for_weather",right_on="datetime")
taxi_trips_with_weather.sample(11)
# Out:
#                                         trip_id  \
# 17253  46f6656044f1bf5e8613203ecdbf73e46d1484a7
# 20758  b346133d754e406cf863d4c78c772686c78bea0b
# 4688   3d6e089be0933c6143825b00d4d53da0d4083c78
# 3470   5b7d5007a531d5aaf30b86a7a5dae59e1c5dd5b8
# 1034   ea708a1176ee752ec569ab9d059dbbcd7f962e14
# 11122  9c83254270e26b7526c36c6f321fa051fcbe8748
# 7915   cfad2b816318941fa9bacbff1ef90a1665e4bab6
# 18158  2fe9fcc028612e5976d660e0ff9f6f8d39df0d6e
# 2805   a8443ff28ded79740c7c002c8dac483a112be5d1
# 1479   641bd52f0a05ef4d6febfb4f3f0c0f0ea7dd309c
# 7957   aeb844d66171c577343cf1c865d5c4c766cf276c
#
#                                                  taxi_id trip_start_timestamp  \
# 17253  6b6dc04e7b06da4f1dc50dee727d9ef2d1c2df22a009b4...  2025-09-26 09:30:00
# 20758  b3ee94a13b61037620cbbfc6a4a106d2ad628a06f0988f...  2025-09-26 00:45:00
# 4688   4e2f65a7aa0041c47a12b57b49aa592b2145daacdfe37a...  2025-09-26 18:30:00
# 3470   d41e198fbed96bdbe8649a6c626cfeb16e5f82ca39a0c7...  2025-09-26 19:15:00
# 1034   cb80f58820478e379627f16b373d5e29ca5343b9307b65...  2025-09-26 21:45:00
# 11122  053486cd912ae399d28c26d6976cf507140df78ec57d09...  2025-09-26 14:00:00
# 7915   be5db5106829df724988f3e5da5f59672e95972e57ec75...  2025-09-26 16:15:00
# 18158  259d38cfdbc9ac6f9bb01f0df740e0ddf4a631a70bbdd6...  2025-09-26 08:45:00
# 2805   5c05237ba3c9c58aeafc5622ebe12d6c9a7f40234ef36f...  2025-09-26 19:45:00
# 1479   4e2f65a7aa0041c47a12b57b49aa592b2145daacdfe37a...  2025-09-26 21:15:00
# 7957   4489496317d593d220fd48f54f9db2732a9a1365fb5206...  2025-09-26 16:15:00
#
#             trip_end_timestamp trip_seconds trip_miles  \
# 17253  2025-09-26T10:00:00.000         2141      15.03
# 20758  2025-09-26T00:45:00.000          180        0.4
# 4688   2025-09-26T18:30:00.000            0          0
# 3470   2025-09-26T19:45:00.000         1715       8.73
# 1034   2025-09-26T22:00:00.000         1077       4.42
# 11122  2025-09-26T14:15:00.000          576       1.08
# 7915   2025-09-26T17:45:00.000         4675      25.64
# 18158  2025-09-26T08:45:00.000          360        0.8
# 2805   2025-09-26T19:45:00.000          673        0.5
# 1479   2025-09-26T21:30:00.000          600          1
# 7957   2025-09-26T16:30:00.000          669        0.8
#
#       pickup_community_area_id dropoff_community_area_id   fare  tips tolls  \
# 17253                       56                         7   39.5     9     0
# 20758                        8                         8    4.5     0     0
# 4688                        32                        32   3.25     0     0
# 3470                        32                         4  31.38     0     0
# 1034                         8                        33  15.25  3.15     0
# 11122                        8                         8    8.5   2.4     0
# 7915                        76                        41   64.5  13.8     0
# 18158                       32                        32      6     2     0
# 2805                         8                         8      7     0     0
# 1479                         8                         8      7     0     0
# 7957                         8                         8      7     0     0
#
#       extras trip_total payment_type                            company  \
# 17253      5         54       Mobile                           Sun Taxi
# 20758      2        6.5         Cash  Transit Administrative Center Inc
# 4688       0       3.25         Cash  Transit Administrative Center Inc
# 3470       0      31.88       Mobile                   Medallion Leasin
# 1034       0       18.9  Credit Card                       City Service
# 11122      0       11.4       Mobile                           Sun Taxi
# 7915       4       82.8  Credit Card     Star North Taxi Management Llc
# 18158      1          9  Credit Card      Taxicab Insurance Agency  LLC
# 2805       0          7         Cash                          Flash Cab
# 1479       1          8         Cash  Transit Administrative Center Inc
# 7957       0        7.5       Mobile                           Sun Taxi
#
#       pickup_centroid_latitude pickup_centroid_longitude  \
# 17253              41.79259236             -87.769615453
# 20758             41.899602111             -87.633308037
# 4688              41.884987192             -87.620992913
# 3470              41.878865584             -87.625192142
# 1034              41.899155613             -87.626210532
# 11122             41.892042136              -87.63186395
# 7915               41.97907082             -87.903039661
# 18158             41.880994471             -87.632746489
# 2805               41.89503345             -87.619710672
# 1479              41.899602111             -87.633308037
# 7957              41.900221297             -87.629105186
#
#       dropoff_centroid_latitude dropoff_centroid_longitude  \
# 17253              41.922686284              -87.649488729
# 20758              41.899602111              -87.633308037
# 4688               41.884987192              -87.620992913
# 3470               41.975170943              -87.687515515
# 1034               41.859349715              -87.617358006
# 11122              41.899155613              -87.626210532
# 7915               41.790506261              -87.583143717
# 18158              41.880994471              -87.632746489
# 2805               41.892507781              -87.626214906
# 1479               41.899602111              -87.633308037
# 7957               41.892042136               -87.63186395
#
#                       :id           :version               :created_at  \
# 17253  row-pn6s~yrtp~24rs  rv-mrcs.3n9m-6xhg  2025-10-09T18:15:56.782Z
# 20758  row-4pse_uh6i-t9pp  rv-5hwi_jd84_v88b  2025-10-09T18:15:56.782Z
# 4688   row-tvss.jjiw~3ha4  rv-mjcs.zaep_dwpi  2025-10-09T18:15:56.782Z
# 3470   row-jt9f.dmkd.b2za  rv-473j-h795_9uc4  2025-10-09T18:15:56.782Z
# 1034   row-kyai.f5ed.94ud  rv-gikz.vtuf-tgbv  2025-10-09T18:15:56.782Z
# 11122  row-xmm5_rxa8_zd77  rv-662z_exn9.kis3  2025-10-09T18:15:56.782Z
# 7915   row-t5ia-zyt6_vy3g  rv-5maj-u67t~47fx  2025-10-09T18:15:56.782Z
# 18158  row-9ywj-u4v6.wrxt  rv-yg7p_93rb_365f  2025-10-09T18:15:56.782Z
# 2805   row-gsz7-grym~z2qt  rv-ye8y.hji2_5kx2  2025-10-09T18:15:56.782Z
# 1479   row-3i7s-c3u8~gsbz  rv-gj4k-8rzy-jnyh  2025-10-09T18:15:56.782Z
# 7957   row-rk79-7fti~hnqt  rv-bnqg_mdbb_wuxt  2025-10-09T18:15:56.782Z
#
#                     :updated_at datetime_for_weather trip_start_date  \
# 17253  2025-10-09T18:15:56.782Z  2025-09-26 09:00:00      2025-09-26
# 20758  2025-10-09T18:15:56.782Z  2025-09-26 00:00:00      2025-09-26
# 4688   2025-10-09T18:15:56.782Z  2025-09-26 18:00:00      2025-09-26
# 3470   2025-10-09T18:15:56.782Z  2025-09-26 19:00:00      2025-09-26
# 1034   2025-10-09T18:15:56.782Z  2025-09-26 21:00:00      2025-09-26
# 11122  2025-10-09T18:15:56.782Z  2025-09-26 14:00:00      2025-09-26
# 7915   2025-10-09T18:15:56.782Z  2025-09-26 16:00:00      2025-09-26
# 18158  2025-10-09T18:15:56.782Z  2025-09-26 08:00:00      2025-09-26
# 2805   2025-10-09T18:15:56.782Z  2025-09-26 19:00:00      2025-09-26
# 1479   2025-10-09T18:15:56.782Z  2025-09-26 21:00:00      2025-09-26
# 7957   2025-10-09T18:15:56.782Z  2025-09-26 16:00:00      2025-09-26
#
#                  datetime  temperature  wind_speed  rain  precipitation
# 17253 2025-09-26 09:00:00         14.7         6.3   0.0            0.0
# 20758 2025-09-26 00:00:00         17.5         2.2   0.0            0.0
# 4688  2025-09-26 18:00:00         24.9         9.0   0.0            0.0
# 3470  2025-09-26 19:00:00         25.6         8.6   0.0            0.0
# 1034  2025-09-26 21:00:00         25.9         9.2   0.0            0.0
# 11122 2025-09-26 14:00:00         16.8         7.7   0.0            0.0
# 7915  2025-09-26 16:00:00         22.1         9.0   0.0            0.0
# 18158 2025-09-26 08:00:00         15.0         6.2   0.0            0.0
# 2805  2025-09-26 19:00:00         25.6         8.6   0.0            0.0
# 1479  2025-09-26 21:00:00         25.9         9.2   0.0            0.0
# 7957  2025-09-26 16:00:00         22.1         9.0   0.0            0.0

# %% [markdown]
# ### Trasformation data type conversions

# %%
taxi_trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21003 entries, 0 to 23173
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   trip_id                     21003 non-null  object
#  1   taxi_id                     21003 non-null  object
#  2   trip_start_timestamp        21003 non-null  datetime64[ns]
#  3   trip_end_timestamp          21003 non-null  object
#  4   trip_seconds                21003 non-null  object
#  5   trip_miles                  21003 non-null  object
#  6   pickup_community_area_id    21003 non-null  object
#  7   dropoff_community_area_id   21003 non-null  object
#  8   fare                        21003 non-null  object
#  9   tips                        21003 non-null  object
#  10  tolls                       21003 non-null  object
#  11  extras                      21003 non-null  object
#  12  trip_total                  21003 non-null  object
#  13  payment_type                21003 non-null  object
#  14  company                     21003 non-null  object
#  15  pickup_centroid_latitude    21003 non-null  object
#  16  pickup_centroid_longitude   21003 non-null  object
#  17  dropoff_centroid_latitude   21003 non-null  object
#  18  dropoff_centroid_longitude  21003 non-null  object
#  19  :id                         21003 non-null  object
#  20  :version                    21003 non-null  object
#  21  :created_at                 21003 non-null  object
#  22  :updated_at                 21003 non-null  object
#  23  datetime_for_weather        21003 non-null  datetime64[ns]
#  24  trip_start_date             21003 non-null  object
# dtypes: datetime64[ns](2), object(23)
# memory usage: 4.2+ MB

# %%
taxi_trips_original=taxi_trips.copy()

# %%
data_types={
    "trip_seconds":"int32",
    "trip_miles":"float",
    "pickup_community_area_id":"int8",
    "dropoff_community_area_id":"int8",
    "fare":"float",
    "tips":"float",
    "tolls":"float",
    "extras":"float",
    "trip_total":"float",
    "pickup_centroid_latitude":"float",
    "pickup_centroid_longitude":"float",
    "dropoff_centroid_latitude":"float",
    "dropoff_centroid_longitude":"float",
}

taxi_trips=taxi_trips.astype(data_types)

# %%
taxi_trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21003 entries, 0 to 23173
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   trip_id                     21003 non-null  object
#  1   taxi_id                     21003 non-null  object
#  2   trip_start_timestamp        21003 non-null  datetime64[ns]
#  3   trip_end_timestamp          21003 non-null  object
#  4   trip_seconds                21003 non-null  int32
#  5   trip_miles                  21003 non-null  float64
#  6   pickup_community_area_id    21003 non-null  int8
#  7   dropoff_community_area_id   21003 non-null  int8
#  8   fare                        21003 non-null  float64
#  9   tips                        21003 non-null  float64
#  10  tolls                       21003 non-null  float64
#  11  extras                      21003 non-null  float64
#  12  trip_total                  21003 non-null  float64
#  13  payment_type                21003 non-null  object
#  14  company                     21003 non-null  object
#  15  pickup_centroid_latitude    21003 non-null  float64
#  16  pickup_centroid_longitude   21003 non-null  float64
#  17  dropoff_centroid_latitude   21003 non-null  float64
#  18  dropoff_centroid_longitude  21003 non-null  float64
#  19  :id                         21003 non-null  object
#  20  :version                    21003 non-null  object
#  21  :created_at                 21003 non-null  object
#  22  :updated_at                 21003 non-null  object
#  23  datetime_for_weather        21003 non-null  datetime64[ns]
#  24  trip_start_date             21003 non-null  object
# dtypes: datetime64[ns](2), float64(10), int32(1), int8(2), object(10)
# memory usage: 3.8+ MB

# %% [markdown]
# ### Memory usage

# %%
orig_mem=taxi_trips_original.memory_usage(deep=True).sum()
opt_mem=taxi_trips.memory_usage(deep=True).sum()

diff=(orig_mem-opt_mem)/orig_mem*100
print(f"Original:{orig_mem:,} bytes")
print(f"Optimized:{opt_mem:,} bytes")
print(f"Memory reduced by:{diff:.2f}%")
# Out:
# Original:31,776,981 bytes
# Optimized:18,708,917 bytes
# Memory reduced by:41.12%

# %% [markdown]
# ### Sanity check

# %%
taxi_trips.describe()
# Out:
#                 trip_start_timestamp  trip_seconds    trip_miles  \
# count                          21003  21003.000000  21003.000000
# mean   2025-09-26 14:14:46.759034624   1256.093939      5.738718
# min              2025-09-26 00:00:00      0.000000      0.000000
# 25%              2025-09-26 10:45:00    481.000000      1.110000
# 50%              2025-09-26 14:30:00    850.000000      2.590000
# 75%              2025-09-26 18:00:00   1657.000000     10.290000
# max              2025-09-26 23:45:00  67341.000000     49.110000
# std                              NaN   1689.151330      6.217482
#
#        pickup_community_area_id  dropoff_community_area_id          fare  \
# count              21003.000000               21003.000000  21003.000000
# mean                  30.584202                  25.041708     20.747713
# min                    1.000000                   1.000000      0.000000
# 25%                    8.000000                   8.000000      8.500000
# 50%                   28.000000                  28.000000     13.430000
# 75%                   38.000000                  32.000000     30.500000
# max                   77.000000                  77.000000   4188.000000
# std                   24.377823                  20.185516     33.194562
#
#                tips         tolls        extras    trip_total  \
# count  21003.000000  21003.000000  21003.000000  21003.000000
# mean       2.307297      0.007444      1.180096     24.537149
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000     10.000000
# 50%        0.000000      0.000000      0.000000     15.300000
# 75%        3.000000      0.000000      1.000000     32.000000
# max       60.000000     12.000000    761.000000   4188.000000
# std        3.853394      0.179433      6.511650     35.493453
#
#        pickup_centroid_latitude  pickup_centroid_longitude  \
# count              21003.000000               21003.000000
# mean                  41.897005                 -87.679706
# min                   41.660136                 -87.913625
# 25%                   41.878866                 -87.663518
# 50%                   41.892508                 -87.633308
# 75%                   41.943155                 -87.625192
# max                   42.009623                 -87.534903
# std                    0.059797                   0.098692
#
#        dropoff_centroid_latitude  dropoff_centroid_longitude  \
# count               21003.000000                21003.000000
# mean                   41.891547                  -87.655905
# min                    41.660136                  -87.913625
# 25%                    41.878866                  -87.657233
# 50%                    41.892042                  -87.633308
# 75%                    41.907520                  -87.622173
# max                    42.009623                  -87.534903
# std                     0.055162                    0.066337
#
#                 datetime_for_weather
# count                          21003
# mean   2025-09-26 13:52:17.380374272
# min              2025-09-26 00:00:00
# 25%              2025-09-26 10:00:00
# 50%              2025-09-26 14:00:00
# 75%              2025-09-26 18:00:00
# max              2025-09-26 23:00:00
# std                              NaN

# %%
taxi_trips[taxi_trips["trip_end_timestamp"]==taxi_trips["trip_end_timestamp"].max()]
# Out:
#                                        trip_id  \
# 3432  c31c7254060f366cfa39ba7c72b01aa2d7844e63
#
#                                                 taxi_id trip_start_timestamp  \
# 3432  cb3bd991c2f7932527ef9d5f341674dfba53745f25fe3e...  2025-09-26 19:30:00
#
#            trip_end_timestamp  trip_seconds  trip_miles  \
# 3432  2025-09-27T13:00:00.000         63044        8.73
#
#       pickup_community_area_id  dropoff_community_area_id  fare  tips  tolls  \
# 3432                        28                         69  23.5   0.0    0.0
#
#       extras  trip_total payment_type                       company  \
# 3432     0.0        23.5         Cash  Blue Ribbon Taxi Association
#
#       pickup_centroid_latitude  pickup_centroid_longitude  \
# 3432                 41.874005                 -87.663518
#
#       dropoff_centroid_latitude  dropoff_centroid_longitude  \
# 3432                  41.763247                  -87.616134
#
#                      :id           :version               :created_at  \
# 3432  row-csau~dmid_szuf  rv-4a6p_xuir_qs3b  2025-10-09T18:15:56.782Z
#
#                    :updated_at datetime_for_weather trip_start_date
# 3432  2025-10-09T18:15:56.782Z  2025-09-26 19:00:00      2025-09-26

# %%
taxi_trips[taxi_trips["trip_seconds"]==taxi_trips["trip_seconds"].max()]
# Out:
#                                        trip_id  \
# 5900  bef4fbe286eddcab707ab6d6c19f3d9488e61afc
#
#                                                 taxi_id trip_start_timestamp  \
# 5900  ce54c7c28cb19a2cea84881f18dba17780375cc59a8c8f...  2025-09-26 18:00:00
#
#            trip_end_timestamp  trip_seconds  trip_miles  \
# 5900  2025-09-27T12:45:00.000         67341       11.07
#
#       pickup_community_area_id  dropoff_community_area_id   fare  tips  tolls  \
# 5900                         6                         76  67.75   0.0    0.0
#
#       extras  trip_total payment_type                       company  \
# 5900     0.0       67.75         Cash  Taxicab Insurance Agency Llc
#
#       pickup_centroid_latitude  pickup_centroid_longitude  \
# 5900                  41.94914                 -87.656804
#
#       dropoff_centroid_latitude  dropoff_centroid_longitude  \
# 5900                  41.979071                   -87.90304
#
#                      :id           :version               :created_at  \
# 5900  row-y7td.eep8_34wz  rv-bphv_cew8~n9kf  2025-10-09T18:15:56.782Z
#
#                    :updated_at datetime_for_weather trip_start_date
# 5900  2025-10-09T18:15:56.782Z  2025-09-26 18:00:00      2025-09-26

# %%
taxi_trips[taxi_trips["fare"]==taxi_trips["fare"].max()]
# Out:
#                                         trip_id  \
# 11966  bed04cfe4ab77a897a1e7e3bf4b83595109d8a87
#
#                                                  taxi_id trip_start_timestamp  \
# 11966  bc8f828bfabea08242e8ba5d7283722378869f674da074...  2025-09-26 14:15:00
#
#             trip_end_timestamp  trip_seconds  trip_miles  \
# 11966  2025-09-26T14:45:00.000          1229         0.0
#
#        pickup_community_area_id  dropoff_community_area_id    fare  tips  \
# 11966                        43                         33  4188.0   0.0
#
#        tolls  extras  trip_total payment_type                       company  \
# 11966    0.0     0.0      4188.0         Cash  Tac - Yellow Cab Association
#
#        pickup_centroid_latitude  pickup_centroid_longitude  \
# 11966                 41.761578                 -87.572782
#
#        dropoff_centroid_latitude  dropoff_centroid_longitude  \
# 11966                  41.857184                  -87.620335
#
#                       :id           :version               :created_at  \
# 11966  row-ztq2_6s4d~758x  rv-hyk2_ewan_j6bm  2025-10-09T18:15:56.782Z
#
#                     :updated_at datetime_for_weather trip_start_date
# 11966  2025-10-09T18:15:56.782Z  2025-09-26 14:00:00      2025-09-26

# %% [markdown]
# ### payment type dimension

# %%
taxi_trips["payment_type"].unique()
# Out:
# array(['Mobile', 'Credit Card', 'Prcard', 'Cash', 'Unknown', 'No Charge',
#        'Dispute'], dtype=object)

# %%
dim_payment_type=taxi_trips["payment_type"].drop_duplicates().reset_index(drop=True)
dim_payment_type
# Out:
# 0         Mobile
# 1    Credit Card
# 2         Prcard
# 3           Cash
# 4        Unknown
# 5      No Charge
# 6        Dispute
# Name: payment_type, dtype: object

# %%
for i in range(1,len(dim_payment_type)+1):
    print (i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
dim_payment_type=pd.DataFrame(
    {"payment_type_id":range(1,len(dim_payment_type)+1),
     "payment_type":dim_payment_type
    }
)
dim_payment_type
# Out:
#    payment_type_id payment_type
# 0                1       Mobile
# 1                2  Credit Card
# 2                3       Prcard
# 3                4         Cash
# 4                5      Unknown
# 5                6    No Charge
# 6                7      Dispute

# %% [markdown]
# ### Company dimension

# %%
dim_company=taxi_trips["company"].drop_duplicates().reset_index(drop=True)
dim_company=pd.DataFrame(
    {"company_id":range(1,len(dim_company)+1),
     "company":dim_company
    }
)
dim_company
# Out:
#     company_id                               company
# 0            1          Tac - Yellow Cab Association
# 1            2                             Flash Cab
# 2            3                            Globe Taxi
# 3            4                      Medallion Leasin
# 4            5                  Chicago Independents
# 5            6          Blue Ribbon Taxi Association
# 6            7            Tac - Checker Cab Dispatch
# 7            8                           5 Star Taxi
# 8            9     Transit Administrative Center Inc
# 9           10                          City Service
# 10          11                              Sun Taxi
# 11          12          Taxicab Insurance Agency Llc
# 12          13           Choice Taxi Association Inc
# 13          14         Chicago City Taxi Association
# 14          15         Taxicab Insurance Agency  LLC
# 15          16  Patriot Taxi Dba Peace Taxi Associat
# 16          17         312 Medallion Management Corp
# 17          18                       Chicago Taxicab
# 18          19           3556 - 36214 RC Andrews Cab
# 19          20        Star North Taxi Management Llc
# 20          21                               Top Cab
# 21          22                           Wolley Taxi
# 22          23                            Setare Inc
# 23          24        Tac - American United Dispatch
# 24          25                Tac - Yellow Non Color
# 25          26           Tac - Blue Diamond Dispatch
# 26          27                 Koam Taxi Association
# 27          28            5167 - 71969 5167 Taxi Inc
# 28          29                             U Taxicab
# 29          30           6574 - Babylon Express Inc.
# 30          31                     Metro Jet Taxi A.
# 31          32          4053 - 40193 Adwar H. Nikola

# %% [markdown]
# ### merging back to the fact table

# %%
fact_taxi_trips=taxi_trips.merge(dim_payment_type,on="payment_type")
fact_taxi_trips=fact_taxi_trips.merge(dim_company,on="company")
fact_taxi_trips.sample(5)
# Out:
#                                         trip_id  \
# 9650   fbbd29ce6340ee597273fbaa36241accf9b2217c
# 4442   d2c4d1454c5ddc889b6c81dd9118ddc3f4c34234
# 14998  f2656acdd6512f402f973da7354e3a61d2e973c5
# 14730  ca5ac3863736df9e130464d2534062da7d134555
# 14804  8fc039cfd017fd4ef28e8195e42f6bdbd0f66fdb
#
#                                                  taxi_id trip_start_timestamp  \
# 9650   da6f829d43ef9293b94c21a502d12c9a48b2a7d7b6a886...  2025-09-26 15:00:00
# 4442   3577d72a8bf30406c1346a5e178b7f3a0ce8e1f966f59a...  2025-09-26 18:30:00
# 14998  67b8283f19334dd9f9e2d36e9a9fbd2c4f0da9dd3390bf...  2025-09-26 11:15:00
# 14730  79ed9ac0abaaf810157e54af0f923489a9560aa0310479...  2025-09-26 11:30:00
# 14804  ed5ea8aa629c794c3ecfef8ef582d7b6077a7a4c25e000...  2025-09-26 11:30:00
#
#             trip_end_timestamp  trip_seconds  trip_miles  \
# 9650   2025-09-26T15:15:00.000          1018        2.70
# 4442   2025-09-26T18:30:00.000           240        0.90
# 14998  2025-09-26T11:15:00.000           480        1.80
# 14730  2025-09-26T11:45:00.000           736        1.66
# 14804  2025-09-26T12:30:00.000          3154       18.68
#
#        pickup_community_area_id  dropoff_community_area_id   fare  tips  \
# 9650                          7                         32  11.75  2.00
# 4442                          8                          8   5.75  0.00
# 14998                        33                         32   8.25  2.00
# 14730                         8                         28   9.00  3.00
# 14804                        32                         76  48.25  9.75
#
#        tolls  extras  trip_total payment_type  \
# 9650     0.0     0.0       14.25  Credit Card
# 4442     0.0     2.0        7.75         Cash
# 14998    0.0     0.0       10.25  Credit Card
# 14730    0.0     0.0       12.50  Credit Card
# 14804    0.0     0.0       58.50  Credit Card
#
#                                  company  pickup_centroid_latitude  \
# 9650               Koam Taxi Association                 41.922083
# 4442   Transit Administrative Center Inc                 41.891972
# 14998  Transit Administrative Center Inc                 41.857184
# 14730       Taxicab Insurance Agency Llc                 41.890922
# 14804               Chicago Independents                 41.884987
#
#        pickup_centroid_longitude  dropoff_centroid_latitude  \
# 9650                  -87.634156                  41.880994
# 4442                  -87.612945                  41.890922
# 14998                 -87.620335                  41.878866
# 14730                 -87.618868                  41.879255
# 14804                 -87.620993                  41.979071
#
#        dropoff_centroid_longitude                 :id           :version  \
# 9650                   -87.632746  row-pwx7~hex6.c56t  rv-t4ig-vprg.u7pc
# 4442                   -87.618868  row-esrt-v954.vst8  rv-ziu9_geuj_hr4e
# 14998                  -87.625192  row-mgxi~676j.rejj  rv-g26y_h6nk.ycxh
# 14730                  -87.642649  row-vwzf_b8bt~iyp6  rv-zucv-ha88.bm76
# 14804                  -87.903040  row-r4ex.e33e.iiz8  rv-b5m8_hvvq~7be2
#
#                     :created_at               :updated_at  \
# 9650   2025-10-09T18:15:56.782Z  2025-10-09T18:15:56.782Z
# 4442   2025-10-09T18:15:56.782Z  2025-10-09T18:15:56.782Z
# 14998  2025-10-09T18:15:56.782Z  2025-10-09T18:15:56.782Z
# 14730  2025-10-09T18:15:56.782Z  2025-10-09T18:15:56.782Z
# 14804  2025-10-09T18:15:56.782Z  2025-10-09T18:15:56.782Z
#
#       datetime_for_weather trip_start_date  payment_type_id  company_id
# 9650   2025-09-26 15:00:00      2025-09-26                2          27
# 4442   2025-09-26 18:00:00      2025-09-26                4           9
# 14998  2025-09-26 11:00:00      2025-09-26                2           9
# 14730  2025-09-26 11:00:00      2025-09-26                2          12
# 14804  2025-09-26 11:00:00      2025-09-26                2           5

# %%
fact_taxi_trips.drop(["payment_type","company"],axis=1,inplace=True)
fact_taxi_trips.sample(5)
# Out:
#                                         trip_id  \
# 457    f85a267ca412d182f3dcea31041cffe343872428
# 6966   66e70c5068e7b25bc658f9feea9b46c94f3592c0
# 15027  d5f41dec27b12e6cf22c62c18184a4d3780ca31a
# 18351  766cf70ee7353be977d6f44ff32839c3dfaf7cd1
# 20402  cac61f2e37436ec9b39cb28e9ba7ffa9162120bd
#
#                                                  taxi_id trip_start_timestamp  \
# 457    15bd3003357b5782fa70b8adcb0690262b47d1ef234c12...  2025-09-26 22:45:00
# 6966   fd4c6f99a5a84e4ee477beb7cc4ca29db1943fdd145c8c...  2025-09-26 17:00:00
# 15027  6e0a0360a9107f3cc0064a80f49f33a7f53e8aa6232d66...  2025-09-26 11:15:00
# 18351  6d869f9e0b9021de42c3fe26664b8f87e0da69245bc002...  2025-09-26 08:30:00
# 20402  511fc9cb2efb73fcb0fa664156beafbfcef79e71de57bf...  2025-09-26 04:45:00
#
#             trip_end_timestamp  trip_seconds  trip_miles  \
# 457    2025-09-26T22:45:00.000           373        1.46
# 6966   2025-09-26T17:15:00.000          1164        1.86
# 15027  2025-09-26T11:15:00.000           396        1.34
# 18351  2025-09-26T08:45:00.000           900        2.70
# 20402  2025-09-26T05:15:00.000          1941       17.44
#
#        pickup_community_area_id  dropoff_community_area_id   fare  tips  \
# 457                          41                         69   8.16   0.0
# 6966                          8                         28  11.77   0.0
# 15027                        33                         32   9.14   0.0
# 18351                        32                         28  11.00   0.0
# 20402                        32                         76  43.50   0.0
#
#        tolls  extras  trip_total  pickup_centroid_latitude  \
# 457      0.0     0.0        8.66                 41.794090
# 6966     0.0     0.0       12.27                 41.895033
# 15027    0.0     0.0        9.64                 41.859350
# 18351    0.0     6.0       17.00                 41.880994
# 20402    0.0     0.0       44.00                 41.884987
#
#        pickup_centroid_longitude  dropoff_centroid_latitude  \
# 457                   -87.592311                  41.763247
# 6966                  -87.619711                  41.885281
# 15027                 -87.617358                  41.884987
# 18351                 -87.632746                  41.879255
# 20402                 -87.620993                  41.979071
#
#        dropoff_centroid_longitude                 :id           :version  \
# 457                    -87.616134  row-fh6v~b7uv-75dc  rv-rdt9.ctm6.4q2s
# 6966                   -87.657233  row-qkt4~suye_fri4  rv-buj4-nvf2.m464
# 15027                  -87.620993  row-9m3b_fj4s.td9t  rv-y8uh.wvvs~mxva
# 18351                  -87.642649  row-ep72-9pei-2r9q  rv-ygax-xr3p_eswa
# 20402                  -87.903040  row-qg3i_4dfg-v437  rv-w244~i5bm.fvbb
#
#                     :created_at               :updated_at  \
# 457    2025-10-09T18:15:56.782Z  2025-10-09T18:15:56.782Z
# 6966   2025-10-09T18:15:56.782Z  2025-10-09T18:15:56.782Z
# 15027  2025-10-09T18:15:56.782Z  2025-10-09T18:15:56.782Z
# 18351  2025-10-09T18:15:56.782Z  2025-10-09T18:15:56.782Z
# 20402  2025-10-09T18:15:56.782Z  2025-10-09T18:15:56.782Z
#
#       datetime_for_weather trip_start_date  payment_type_id  company_id
# 457    2025-09-26 22:00:00      2025-09-26                1          12
# 6966   2025-09-26 17:00:00      2025-09-26                1           5
# 15027  2025-09-26 11:00:00      2025-09-26                1           2
# 18351  2025-09-26 08:00:00      2025-09-26                4           9
# 20402  2025-09-26 04:00:00      2025-09-26                2          11

# %%
dim_payment_type.to_csv("dim_payment_type.csv",index=False)
dim_company.to_csv("dim_company.csv",index=False)

# %% [markdown]
# ### Create update loogic for dimension tables

# %%
dim_payment_type=taxi_trips["payment_type"].drop_duplicates().reset_index(drop=True)
dim_payment_type=pd.DataFrame(
    {"payment_type_id":range(1,len(dim_payment_type)+1),
     "payment_type":dim_payment_type
    }
)
dummy_payment_type_data=[
    {"payment_type":"Credit Card"},
    {"payment_type":"x"},
    {"payment_type":"y"},
    {"payment_type":"x"},
]
dummy_payment_type_data_df=pd.DataFrame(dummy_payment_type_data)

dummy_payment_type_data_df
#modellezük a holnap letöltött adatok között megjelenő esetleges új adatelemeket mesterséges duplikációval ( új payment type)
# Out:
#   payment_type
# 0  Credit Card
# 1            x
# 2            y
# 3            x

# %%
todays_payment_types=pd.DataFrame(dummy_payment_type_data_df["payment_type"].unique(),columns=["payment_type"])
#kivesszük az ismétlődést és az oszlop neve payment type lesz
new_payment_type=todays_payment_types[~todays_payment_types["payment_type"].isin(dim_payment_type["payment_type"])]
#tilde jel a pythonban a NOT, tehát nincs benne az mai adat a meglévőben azt teszi az újba

new_payment_type
# Out:
#   payment_type
# 1            x
# 2            y

# %%
if not new_payment_type.empty:
    max_id=dim_payment_type["payment_type_id"].max()
    new_payment_type["payment_type_id"]=range(max_id+1,max_id+1+len(new_payment_type))
    dim_payment_type=pd.concat([dim_payment_type,new_payment_type],ignore_index=True)

dim_payment_type
# Out:
# C:\Users\dmcszs87\AppData\Local\Temp\ipykernel_10984\2083938348.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_payment_type["payment_type_id"]=range(max_id+1,max_id+1+len(new_payment_type))
#    payment_type_id payment_type
# 0                1       Mobile
# 1                2  Credit Card
# 2                3       Prcard
# 3                4         Cash
# 4                5      Unknown
# 5                6    No Charge
# 6                7      Dispute
# 7                8            x
# 8                9            y

# %%
#testing the logic with different data


dummy_payment_type_data=[
    {"payment_type":"Credit Card"},
    {"payment_type":"x"},
    {"payment_type":"z"},
    {"payment_type":"z"},
]
dummy_payment_type_data_df=pd.DataFrame(dummy_payment_type_data)

todays_payment_types=pd.DataFrame(dummy_payment_type_data_df["payment_type"].unique(),columns=["payment_type"])

new_payment_type=todays_payment_types[~todays_payment_types["payment_type"].isin(dim_payment_type["payment_type"])]


if not new_payment_type.empty:
    max_id=dim_payment_type["payment_type_id"].max()
    new_payment_type["payment_type_id"]=range(max_id+1,max_id+1+len(new_payment_type))
    dim_payment_type=pd.concat([dim_payment_type,new_payment_type],ignore_index=True)

dim_payment_type
# Out:
#    payment_type_id payment_type
# 0                1       Mobile
# 1                2  Credit Card
# 2                3       Prcard
# 3                4         Cash
# 4                5      Unknown
# 5                6    No Charge
# 6                7      Dispute
# 7                8            x
# 8                9            y
# 9               10            z

# %%
dim_company.tail()
# Out:
#     company_id                       company
# 27          28    5167 - 71969 5167 Taxi Inc
# 28          29                     U Taxicab
# 29          30   6574 - Babylon Express Inc.
# 30          31             Metro Jet Taxi A.
# 31          32  4053 - 40193 Adwar H. Nikola

# %%
dim_company=taxi_trips["company"].drop_duplicates().reset_index(drop=True)
dim_company=pd.DataFrame(
    {"company_id":range(1,len(dim_company)+1),
     "company":dim_company
    }
)
dummy_company_data=[
    {"company":"4053 - 40193 Adwar H. Nikola"},
    {"company":"x"},
    {"company":"y"},
    {"company":"x"},
]
dummy_company_data_df=pd.DataFrame(dummy_company_data)

todays_company=pd.DataFrame(dummy_company_data_df["company"].unique(),columns=["company"])

new_company=todays_company[~todays_company["company"].isin(dim_company["company"])]

if not new_company.empty:
    max_id=dim_company["company_id"].max()
    new_company["company_id"]=range(max_id+1,max_id+1+len(new_company))
    dim_company=pd.concat([dim_company,new_company],ignore_index=True)

dim_company
# Out:
# C:\Users\dmcszs87\AppData\Local\Temp\ipykernel_10984\2873132810.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_company["company_id"]=range(max_id+1,max_id+1+len(new_company))
#     company_id                               company
# 0            1          Tac - Yellow Cab Association
# 1            2                             Flash Cab
# 2            3                            Globe Taxi
# 3            4                      Medallion Leasin
# 4            5                  Chicago Independents
# 5            6          Blue Ribbon Taxi Association
# 6            7            Tac - Checker Cab Dispatch
# 7            8                           5 Star Taxi
# 8            9     Transit Administrative Center Inc
# 9           10                          City Service
# 10          11                              Sun Taxi
# 11          12          Taxicab Insurance Agency Llc
# 12          13           Choice Taxi Association Inc
# 13          14         Chicago City Taxi Association
# 14          15         Taxicab Insurance Agency  LLC
# 15          16  Patriot Taxi Dba Peace Taxi Associat
# 16          17         312 Medallion Management Corp
# 17          18                       Chicago Taxicab
# 18          19           3556 - 36214 RC Andrews Cab
# 19          20        Star North Taxi Management Llc
# 20          21                               Top Cab
# 21          22                           Wolley Taxi
# 22          23                            Setare Inc
# 23          24        Tac - American United Dispatch
# 24          25                Tac - Yellow Non Color
# 25          26           Tac - Blue Diamond Dispatch
# 26          27                 Koam Taxi Association
# 27          28            5167 - 71969 5167 Taxi Inc
# 28          29                             U Taxicab
# 29          30           6574 - Babylon Express Inc.
# 30          31                     Metro Jet Taxi A.
# 31          32          4053 - 40193 Adwar H. Nikola
# 32          33                                     x
# 33          34                                     y
