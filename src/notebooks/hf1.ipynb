# %%
import json

# %%
file_path="C:\\Users\\dmcszs87\\Desktop\\Python kurzus\\AWS\\data\\01_json_scraping\\spotify_playlist.json"

with open(file_path, "r") as file:
    data=json.load(file)

# %%
px=0
pxlow=0
for track in data["contents"]["items"]:
    if(pxlow==0):
        pxlow=track["playCount"]
    else:
        if pxlow>track["playCount"]:
            pxlow=track["playCount"]
            pxlowname=track["name"]

    px+= (track["playCount"]) 

print (data["contents"]["items"][30]["name"])
print (px)
txt2=f"The song with the lowest playcount is \"{pxlowname}\"."
print (txt2)
# Out:
# Style
# 31309112207
# The song with the lowest playcount is "Si No Estás".
